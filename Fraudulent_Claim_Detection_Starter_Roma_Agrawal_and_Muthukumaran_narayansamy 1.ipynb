# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('./insurance_claims.csv')

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
df.replace('?',np.nan,inplace=True)
#this we will fill later with the respective value

#check the no of empty or NA or null now
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                 360
# bodily_injuries                   0
# witnesses                         0
# police_report_available         343
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %%
#drop the authorities as it have only small amount of nulls
#Handle the nulls with the respective median or mean od respective 
#catergherize the column into respective datatype instead of other data type which will be easy for the pre processing 

df = df.dropna(subset=["authorities_contacted"])
df['property_damage'] = df['property_damage'].fillna('NO')
df['police_report_available'] = df['police_report_available'].fillna('NO')
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"\nColumn: {col}")
    print(f"Unique Values Count: {df[col].nunique()}")
    print(f"Value Counts:\n{df[col].value_counts()}\n")
# Out:
# Column: months_as_customer
# Unique Values Count: 384
# Value Counts:
# months_as_customer
# 285    7
# 128    7
# 254    7
# 230    7
# 259    6
#       ..
# 60     1
# 447    1
# 414    1
# 352    1
# 17     1
# Name: count, Length: 384, dtype: int64
#
#
# Column: age
# Unique Values Count: 46
# Value Counts:
# age
# 43    45
# 41    43
# 39    43
# 38    40
# 37    39
# 30    38
# 32    36
# 34    36
# 31    35
# 33    35
# 40    34
# 29    32
# 46    31
# 42    30
# 36    29
# 44    29
# 28    28
# 35    26
# 26    25
# 45    24
# 48    23
# 47    22
# 27    21
# 57    14
# 50    13
# 53    13
# 55    12
# 25    12
# 54    10
# 61    10
# 49     9
# 60     9
# 56     8
# 51     8
# 24     8
# 58     8
# 23     7
# 21     6
# 52     4
# 62     4
# 59     4
# 64     2
# 19     1
# 20     1
# 22     1
# 63     1
# Name: count, dtype: int64
#
#
# Column: policy_number
# Unique Values Count: 909
# Value Counts:
# policy_number
# 521585    1
# 797634    1
# 261905    1
# 674485    1
# 223404    1
#          ..
# 613226    1
# 804410    1
# 553565    1
# 399524    1
# 556080    1
# Name: count, Length: 909, dtype: int64
#
#
# Column: policy_bind_date
# Unique Values Count: 865
# Value Counts:
# policy_bind_date
# 2006-01-01    3
# 1992-04-28    3
# 1992-08-05    3
# 1992-01-05    2
# 2002-12-21    2
#              ..
# 2013-07-07    1
# 2003-07-05    1
# 1995-02-18    1
# 2014-12-13    1
# 1996-11-11    1
# Name: count, Length: 865, dtype: int64
#
#
# Column: policy_state
# Unique Values Count: 3
# Value Counts:
# policy_state
# OH    319
# IL    310
# IN    280
# Name: count, dtype: int64
#
#
# Column: policy_csl
# Unique Values Count: 3
# Value Counts:
# policy_csl
# 100/300     326
# 250/500     316
# 500/1000    267
# Name: count, dtype: int64
#
#
# Column: policy_deductable
# Unique Values Count: 3
# Value Counts:
# policy_deductable
# 1000    317
# 500     315
# 2000    277
# Name: count, dtype: int64
#
#
# Column: policy_annual_premium
# Unique Values Count: 903
# Value Counts:
# policy_annual_premium
# 1362.87    2
# 1215.36    2
# 1524.45    2
# 1374.22    2
# 1558.29    2
#           ..
# 929.70     1
# 1829.63    1
# 904.70     1
# 1243.84    1
# 766.19     1
# Name: count, Length: 903, dtype: int64
#
#
# Column: umbrella_limit
# Unique Values Count: 11
# Value Counts:
# umbrella_limit
#  0           726
#  6000000      50
#  5000000      43
#  4000000      37
#  7000000      24
#  3000000      11
#  8000000       8
#  9000000       4
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
#
#
# Column: insured_zip
# Unique Values Count: 904
# Value Counts:
# insured_zip
# 477695    2
# 469429    2
# 456602    2
# 431202    2
# 446895    2
#          ..
# 460722    1
# 618632    1
# 452204    1
# 454530    1
# 612260    1
# Name: count, Length: 904, dtype: int64
#
#
# Column: insured_sex
# Unique Values Count: 2
# Value Counts:
# insured_sex
# FEMALE    494
# MALE      415
# Name: count, dtype: int64
#
#
# Column: insured_education_level
# Unique Values Count: 7
# Value Counts:
# insured_education_level
# High School    146
# JD             145
# MD             132
# Masters        130
# Associate      129
# PhD            115
# College        112
# Name: count, dtype: int64
#
#
# Column: insured_occupation
# Unique Values Count: 14
# Value Counts:
# insured_occupation
# machine-op-inspct    87
# prof-specialty       77
# tech-support         71
# craft-repair         70
# sales                70
# exec-managerial      68
# transport-moving     67
# priv-house-serv      66
# other-service        61
# armed-forces         59
# protective-serv      58
# adm-clerical         54
# handlers-cleaners    53
# farming-fishing      48
# Name: count, dtype: int64
#
#
# Column: insured_hobbies
# Unique Values Count: 20
# Value Counts:
# insured_hobbies
# reading           58
# exercise          54
# bungie-jumping    52
# camping           50
# movies            50
# hiking            50
# yachting          49
# paintball         49
# golf              47
# skydiving         47
# kayaking          46
# base-jumping      43
# board-games       43
# chess             43
# video-games       43
# polo              42
# dancing           40
# sleeping          38
# cross-fit         34
# basketball        31
# Name: count, dtype: int64
#
#
# Column: insured_relationship
# Unique Values Count: 6
# Value Counts:
# insured_relationship
# own-child         165
# other-relative    164
# husband           156
# not-in-family     156
# wife              139
# unmarried         129
# Name: count, dtype: int64
#
#
# Column: capital-gains
# Unique Values Count: 312
# Value Counts:
# capital-gains
# 0        466
# 46300      5
# 51500      4
# 56700      3
# 51100      3
#         ...
# 48800      1
# 54800      1
# 64000      1
# 56900      1
# 70900      1
# Name: count, Length: 312, dtype: int64
#
#
# Column: capital-loss
# Unique Values Count: 341
# Value Counts:
# capital-loss
#  0        432
# -50300      5
# -45300      4
# -31400      4
# -51000      4
#          ...
# -45500      1
# -71000      1
# -67300      1
# -19700      1
# -32200      1
# Name: count, Length: 341, dtype: int64
#
#
# Column: incident_date
# Unique Values Count: 60
# Value Counts:
# incident_date
# 2015-02-02    25
# 2015-01-07    24
# 2015-02-17    23
# 2015-01-10    23
# 2015-02-04    23
# 2015-01-24    21
# 2015-01-08    21
# 2015-01-30    20
# 2015-01-19    20
# 2015-02-06    19
# 2015-01-14    19
# 2015-02-12    19
# 2015-01-13    18
# 2015-01-12    18
# 2015-02-14    18
# 2015-01-31    18
# 2015-02-23    18
# 2015-02-08    17
# 2015-02-22    17
# 2015-01-21    17
# 2015-02-01    17
# 2015-01-09    17
# 2015-02-21    16
# 2015-01-03    16
# 2015-02-15    16
# 2015-01-20    16
# 2015-02-25    16
# 2015-01-01    16
# 2015-01-06    16
# 2015-02-28    16
# 2015-01-18    15
# 2015-01-16    15
# 2015-02-13    15
# 2015-02-24    15
# 2015-02-18    14
# 2015-02-26    14
# 2015-02-05    14
# 2015-02-16    14
# 2015-01-23    13
# 2015-01-28    13
# 2015-02-20    13
# 2015-01-15    13
# 2015-01-22    13
# 2015-01-17    13
# 2015-01-27    12
# 2015-03-01    12
# 2015-02-27    12
# 2015-02-03    11
# 2015-01-04    11
# 2015-02-09    11
# 2015-01-29    10
# 2015-01-26    10
# 2015-01-25    10
# 2015-02-11     9
# 2015-01-11     9
# 2015-01-02     9
# 2015-02-07     9
# 2015-02-19     8
# 2015-02-10     7
# 2015-01-05     5
# Name: count, dtype: int64
#
#
# Column: incident_type
# Unique Values Count: 4
# Value Counts:
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                53
# Parked Car                   34
# Name: count, dtype: int64
#
#
# Column: collision_type
# Unique Values Count: 3
# Value Counts:
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# Name: count, dtype: int64
#
#
# Column: incident_severity
# Unique Values Count: 4
# Value Counts:
# incident_severity
# Minor Damage      304
# Total Loss        280
# Major Damage      276
# Trivial Damage     49
# Name: count, dtype: int64
#
#
# Column: authorities_contacted
# Unique Values Count: 4
# Value Counts:
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
#
#
# Column: incident_state
# Unique Values Count: 7
# Value Counts:
# incident_state
# NY    246
# SC    225
# WV    196
# NC     97
# VA     96
# PA     29
# OH     20
# Name: count, dtype: int64
#
#
# Column: incident_city
# Unique Values Count: 7
# Value Counts:
# incident_city
# Springfield    145
# Columbus       141
# Northbend      133
# Arlington      129
# Hillsdale      128
# Riverwood      121
# Northbrook     112
# Name: count, dtype: int64
#
#
# Column: incident_location
# Unique Values Count: 909
# Value Counts:
# incident_location
# 9935 4th Drive         1
# 8639 5th Hwy           1
# 4835 Britain Ridge     1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
#                       ..
# 6945 Texas Hwy         1
# 5639 1st Ridge         1
# 3834 Pine St           1
# 1358 Maple St          1
# 1416 Cherokee Ridge    1
# Name: count, Length: 909, dtype: int64
#
#
# Column: incident_hour_of_the_day
# Unique Values Count: 24
# Value Counts:
# incident_hour_of_the_day
# 17    51
# 23    51
# 0     49
# 16    47
# 13    42
# 21    42
# 14    42
# 12    40
# 18    40
# 10    40
# 3     40
# 19    39
# 4     38
# 22    38
# 15    38
# 9     34
# 6     33
# 7     33
# 20    32
# 11    30
# 2     30
# 1     27
# 8     27
# 5     26
# Name: count, dtype: int64
#
#
# Column: number_of_vehicles_involved
# Unique Values Count: 4
# Value Counts:
# number_of_vehicles_involved
# 1    490
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
#
#
# Column: property_damage
# Unique Values Count: 2
# Value Counts:
# property_damage
# NO     633
# YES    276
# Name: count, dtype: int64
#
#
# Column: bodily_injuries
# Unique Values Count: 3
# Value Counts:
# bodily_injuries
# 2    309
# 0    307
# 1    293
# Name: count, dtype: int64
#
#
# Column: witnesses
# Unique Values Count: 4
# Value Counts:
# witnesses
# 2    234
# 0    230
# 1    228
# 3    217
# Name: count, dtype: int64
#
#
# Column: police_report_available
# Unique Values Count: 2
# Value Counts:
# police_report_available
# NO     623
# YES    286
# Name: count, dtype: int64
#
#
# Column: total_claim_amount
# Unique Values Count: 719
# Value Counts:
# total_claim_amount
# 59400    5
# 58500    4
# 60600    4
# 75400    4
# 70290    4
#         ..
# 44880    1
# 82830    1
# 84480    1
# 53020    1
# 5060     1
# Name: count, Length: 719, dtype: int64
#
#
# Column: injury_claim
# Unique Values Count: 616
# Value Counts:
# injury_claim
# 0        24
# 5540      5
# 6340      5
# 13520     5
# 5000      4
#          ..
# 13660     1
# 6370      1
# 4650      1
# 6660      1
# 460       1
# Name: count, Length: 616, dtype: int64
#
#
# Column: property_claim
# Unique Values Count: 603
# Value Counts:
# property_claim
# 0        18
# 11080     5
# 10000     5
# 7000      4
# 11100     4
#          ..
# 3590      1
# 6480      1
# 4580      1
# 4920      1
# 920       1
# Name: count, Length: 603, dtype: int64
#
#
# Column: vehicle_claim
# Unique Values Count: 691
# Value Counts:
# vehicle_claim
# 52080    5
# 33600    5
# 44800    5
# 41760    4
# 46800    4
#         ..
# 43360    1
# 25130    1
# 38940    1
# 47430    1
# 3680     1
# Name: count, Length: 691, dtype: int64
#
#
# Column: auto_make
# Unique Values Count: 14
# Value Counts:
# auto_make
# Suburu        74
# Saab          72
# Dodge         72
# Nissan        69
# Ford          67
# BMW           67
# Chevrolet     66
# Audi          63
# Accura        63
# Toyota        62
# Jeep          62
# Volkswagen    62
# Mercedes      60
# Honda         50
# Name: count, dtype: int64
#
#
# Column: auto_model
# Unique Values Count: 39
# Value Counts:
# auto_model
# RAM               40
# Wrangler          38
# Jetta             33
# A3                33
# MDX               33
# Neon              32
# A5                30
# Legacy            30
# Passat            29
# Pathfinder        27
# Forrestor         26
# F150              25
# 95                25
# Camry             25
# Malibu            25
# 92x               24
# E400              24
# Grand Cherokee    24
# Escape            23
# Maxima            23
# 93                23
# Tahoe             22
# X5                20
# Highlander        20
# CRV               19
# Ultima            19
# Fusion            19
# Silverado         19
# TL                19
# Civic             18
# Impreza           18
# ML350             18
# C300              18
# 3 Series          18
# Corolla           17
# X6                16
# Accord            13
# M5                13
# RSX               11
# Name: count, dtype: int64
#
#
# Column: auto_year
# Unique Values Count: 21
# Value Counts:
# auto_year
# 1995    52
# 2005    51
# 2006    51
# 1999    50
# 2007    48
# 2010    47
# 2009    47
# 2011    47
# 2003    46
# 2013    43
# 2012    43
# 2015    42
# 2008    42
# 1997    42
# 2002    41
# 2014    40
# 2000    38
# 2004    36
# 1996    35
# 1998    35
# 2001    33
# Name: count, dtype: int64
#
#
# Column: fraud_reported
# Unique Values Count: 2
# Value Counts:
# fraud_reported
# N    668
# Y    241
# Name: count, dtype: int64
#
#
# Column: _c39
# Unique Values Count: 0
# Value Counts:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
empty_cols = df.columns[df.isna().all()]
print("Completely empty columns:", list(empty_cols))

df.dropna(axis=1, how='all', inplace=True)
# Out:
# Completely empty columns: ['_c39']

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
negative_values = (numeric_columns < 0).sum()  # Counts negative values per column
print("Negative values per numeric column:\n", negative_values)
# Out:
# Negative values per numeric column:
#  months_as_customer               0
# age                              0
# policy_number                    0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   1
# insured_zip                      0
# capital-gains                    0
# capital-loss                   477
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# bodily_injuries                  0
# witnesses                        0
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# auto_year                        0
# dtype: int64

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
numeric_columns = df.select_dtypes(include=["number"]) 
numeric_columns
# Out:
#      months_as_customer  age  policy_number  policy_deductable  \
# 0                   328   48         521585               1000
# 1                   228   42         342868               2000
# 2                   134   29         687698               2000
# 3                   256   41         227811               2000
# 5                   256   39         104594               1000
# ..                  ...  ...            ...                ...
# 995                   3   38         941851               1000
# 996                 285   41         186934               1000
# 997                 130   34         918516                500
# 998                 458   62         533940               2000
# 999                 456   60         556080               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# 0                  1406.91               0       466132          53300
# 1                  1197.22         5000000       468176              0
# 2                  1413.14         5000000       430632          35100
# 3                  1415.74         6000000       608117          48900
# 5                  1351.10               0       478456              0
# ..                     ...             ...          ...            ...
# 995                1310.80               0       431289              0
# 996                1436.79               0       608177          70900
# 997                1383.49         3000000       442797          35100
# 998                1356.92         5000000       441714              0
# 999                 766.19               0       612260              0
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0               0                         5                            1
# 1               0                         8                            1
# 2               0                         7                            3
# 3          -62400                         5                            1
# 5               0                        19                            3
# ..            ...                       ...                          ...
# 995             0                        20                            1
# 996             0                        23                            1
# 997             0                         4                            3
# 998             0                         2                            1
# 999             0                         6                            1
#
#      bodily_injuries  witnesses  total_claim_amount  injury_claim  \
# 0                  1          2               71610          6510
# 1                  0          0                5070           780
# 2                  2          3               34650          7700
# 3                  1          2               63400          6340
# 5                  0          2               64100          6410
# ..               ...        ...                 ...           ...
# 995                0          1               87200         17440
# 996                2          3              108480         18080
# 997                2          3               67500          7500
# 998                0          1               46980          5220
# 999                0          3                5060           460
#
#      property_claim  vehicle_claim  auto_year
# 0             13020          52080       2004
# 1               780           3510       2007
# 2              3850          23100       2007
# 3              6340          50720       2014
# 5              6410          51280       2003
# ..              ...            ...        ...
# 995            8720          61040       2006
# 996           18080          72320       2015
# 997            7500          52500       1996
# 998            5220          36540       1998
# 999             920           3680       2007
#
# [909 rows x 18 columns]

# %%
df = df[~df["umbrella_limit"]<0]

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
threshold = 0.95 * len(df)  # If 95% of values in a column are unique, drop it
cols_most_unique_values = [col for col in df.columns if df[col].nunique() > threshold]
df.drop(columns=cols_most_unique_values, inplace=True)
print(f"Dropped columns with high unique value proportion: {cols_most_unique_values}")
# Out:
# Dropped columns with high unique value proportion: ['policy_number', 'policy_bind_date', 'policy_annual_premium', 'insured_zip', 'incident_location']

# %%
# Check the dataset
df.shape
# Out:
# (908, 34)

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
df.dtypes
# Out:
# months_as_customer              int64
# age                             int64
# policy_state                   object
# policy_csl                     object
# policy_deductable               int64
# umbrella_limit                  int64
# insured_sex                    object
# insured_education_level        object
# insured_occupation             object
# insured_hobbies                object
# insured_relationship           object
# capital-gains                   int64
# capital-loss                    int64
# incident_date                  object
# incident_type                  object
# collision_type                 object
# incident_severity              object
# authorities_contacted          object
# incident_state                 object
# incident_city                  object
# incident_hour_of_the_day        int64
# number_of_vehicles_involved     int64
# property_damage                object
# bodily_injuries                 int64
# witnesses                       int64
# police_report_available        object
# total_claim_amount              int64
# injury_claim                    int64
# property_claim                  int64
# vehicle_claim                   int64
# auto_make                      object
# auto_model                     object
# auto_year                       int64
# fraud_reported                 object
# dtype: object

# %%
df['incident_date'] = pd.to_datetime(df['incident_date'], errors='coerce')

df['fraud_reported'].replace(to_replace='Y', value=1, inplace=True)
df['fraud_reported'].replace(to_replace='N',  value=0, inplace=True)

# %%
# Check the features of the data again
df.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# umbrella_limit                          int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                          int64
# dtype: object

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = df.drop(['fraud_reported'], axis = 1)
# Put the target variable in y
y = df['fraud_reported']

print("Shape of x :", X.shape)
print("Shape of y :", y.shape)
# Out:
# Shape of x : (908, 33)
# Shape of y : (908,)

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0, stratify =y)

print("Shape of x_train :", X_train.shape)
print("Shape of x_test :", X_test.shape)
print("Shape of y_train :", y_train.shape)
print("Shape of y_test :", y_test.shape)

# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
# Out:
# Shape of x_train : (635, 33)
# Shape of x_test : (273, 33)
# Shape of y_train : (635,)
# Shape of y_test : (273,)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
print(numerical_cols)
# Out:
# Index(['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
X_train[numerical_cols].hist(figsize=(20, 25), bins=30)
plt.suptitle("Distribution of Numerical Columns")
plt.show()

# %%
# Box plots to identify outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=X_train[numerical_cols])
plt.xticks(rotation=90)
plt.yscale("log")
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
correlation_matrix = X_train[numerical_cols].corr()
# Plot Heatmap of the correlation matrix
plt.rcParams['figure.figsize'] = (20, 15)
sns.heatmap(correlation_matrix, annot=True, cmap='Greens')
plt.title('Heat Map for Correlations')
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
sns.countplot(x=y_train, palette="Greens")
plt.title("Class Distribution of Fraudulent vs Legitimate Claims")
plt.show()

# Print percentage of fraud cases
fraud_ratio = y_train.value_counts(normalize=True) * 100
print(fraud_ratio)
# Out:
# fraud_reported
# 0    73.385827
# 1    26.614173
# Name: proportion, dtype: float64

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
def fraud_likelihood_analysis(df, categorical_cols, target_col='fraud_reported'):
    fraud_data = df[categorical_cols].copy()
    fraud_data[target_col] = df[target_col]  # Include target variable

    fraud_likelihood_dict = {}
    
    for col in categorical_cols:
        fraud_rate = fraud_data.groupby(col)[target_col].value_counts(normalize=True).unstack()
        fraud_likelihood_dict[col] = fraud_rate
    
    return fraud_likelihood_dict

# Identify categorical columns
categorical_cols = X_train.select_dtypes(include=['object']).columns

# Compute fraud likelihoods
fraud_likelihood_results = fraud_likelihood_analysis(pd.concat([X_train, y_train], axis=1), categorical_cols)

# Display fraud likelihood for key categorical features
for feature, likelihood_df in fraud_likelihood_results.items():
    print(f"\nFraud likelihood for {feature}:\n{likelihood_df}\n")
# Out:
# Fraud likelihood for policy_state:
# fraud_reported         0         1
# policy_state
# IL              0.736364  0.263636
# IN              0.727273  0.272727
# OH              0.737327  0.262673
#
#
# Fraud likelihood for policy_csl:
# fraud_reported         0         1
# policy_csl
# 100/300         0.723684  0.276316
# 250/500         0.723005  0.276995
# 500/1000        0.757732  0.242268
#
#
# Fraud likelihood for insured_sex:
# fraud_reported         0         1
# insured_sex
# FEMALE          0.750000  0.250000
# MALE            0.715719  0.284281
#
#
# Fraud likelihood for insured_education_level:
# fraud_reported                  0         1
# insured_education_level
# Associate                0.722892  0.277108
# College                  0.706667  0.293333
# High School              0.770000  0.230000
# JD                       0.724490  0.275510
# MD                       0.744681  0.255319
# Masters                  0.724490  0.275510
# PhD                      0.735632  0.264368
#
#
# Fraud likelihood for insured_occupation:
# fraud_reported             0         1
# insured_occupation
# adm-clerical        0.825000  0.175000
# armed-forces        0.744186  0.255814
# craft-repair        0.735849  0.264151
# exec-managerial     0.634615  0.365385
# farming-fishing     0.656250  0.343750
# handlers-cleaners   0.777778  0.222222
# machine-op-inspct   0.733333  0.266667
# other-service       0.804348  0.195652
# priv-house-serv     0.840909  0.159091
# prof-specialty      0.770833  0.229167
# protective-serv     0.710526  0.289474
# sales               0.750000  0.250000
# tech-support        0.673077  0.326923
# transport-moving    0.638298  0.361702
#
#
# Fraud likelihood for insured_hobbies:
# fraud_reported          0         1
# insured_hobbies
# base-jumping     0.703704  0.296296
# basketball       0.807692  0.192308
# board-games      0.655172  0.344828
# bungie-jumping   0.769231  0.230769
# camping          0.891892  0.108108
# chess            0.185185  0.814815
# cross-fit        0.227273  0.772727
# dancing          0.900000  0.100000
# exercise         0.794872  0.205128
# golf             0.900000  0.100000
# hiking           0.705882  0.294118
# kayaking         0.885714  0.114286
# movies           0.766667  0.233333
# paintball        0.722222  0.277778
# polo             0.655172  0.344828
# reading          0.700000  0.300000
# skydiving        0.775000  0.225000
# sleeping         0.875000  0.125000
# video-games      0.766667  0.233333
# yachting         0.741935  0.258065
#
#
# Fraud likelihood for insured_relationship:
# fraud_reported               0         1
# insured_relationship
# husband               0.752475  0.247525
# not-in-family         0.716814  0.283186
# other-relative        0.728070  0.271930
# own-child             0.747826  0.252174
# unmarried             0.744444  0.255556
# wife                  0.715686  0.284314
#
#
# Fraud likelihood for incident_type:
# fraud_reported                   0         1
# incident_type
# Multi-vehicle Collision   0.722772  0.277228
# Parked Car                0.954545  0.045455
# Single Vehicle Collision  0.709559  0.290441
# Vehicle Theft             0.868421  0.131579
#
#
# Fraud likelihood for collision_type:
# fraud_reported          0         1
# collision_type
# Front Collision  0.719780  0.280220
# Rear Collision   0.704663  0.295337
# Side Collision   0.725000  0.275000
#
#
# Fraud likelihood for incident_severity:
# fraud_reported            0         1
# incident_severity
# Major Damage       0.366492  0.633508
# Minor Damage       0.906103  0.093897
# Total Loss         0.868020  0.131980
# Trivial Damage     0.941176  0.058824
#
#
# Fraud likelihood for authorities_contacted:
# fraud_reported                0         1
# authorities_contacted
# Ambulance              0.700680  0.299320
# Fire                   0.704698  0.295302
# Other                  0.687500  0.312500
# Police                 0.815385  0.184615
#
#
# Fraud likelihood for incident_state:
# fraud_reported         0         1
# incident_state
# NC              0.630769  0.369231
# NY              0.755556  0.244444
# OH              0.642857  0.357143
# PA              0.625000  0.375000
# SC              0.718954  0.281046
# VA              0.746667  0.253333
# WV              0.787879  0.212121
#
#
# Fraud likelihood for incident_city:
# fraud_reported         0         1
# incident_city
# Arlington       0.709302  0.290698
# Columbus        0.707071  0.292929
# Hillsdale       0.758242  0.241758
# Northbend       0.736842  0.263158
# Northbrook      0.765432  0.234568
# Riverwood       0.722892  0.277108
# Springfield     0.740000  0.260000
#
#
# Fraud likelihood for property_damage:
# fraud_reported          0         1
# property_damage
# NO               0.733781  0.266219
# YES              0.734043  0.265957
#
#
# Fraud likelihood for police_report_available:
# fraud_reported                  0         1
# police_report_available
# NO                       0.723653  0.276347
# YES                      0.754808  0.245192
#
#
# Fraud likelihood for auto_make:
# fraud_reported         0         1
# auto_make
# Accura          0.784314  0.215686
# Audi            0.625000  0.375000
# BMW             0.659091  0.340909
# Chevrolet       0.690476  0.309524
# Dodge           0.763636  0.236364
# Ford            0.714286  0.285714
# Honda           0.702703  0.297297
# Jeep            0.761905  0.238095
# Mercedes        0.684211  0.315789
# Nissan          0.816327  0.183673
# Saab            0.755102  0.244898
# Suburu          0.750000  0.250000
# Toyota          0.782609  0.217391
# Volkswagen      0.731707  0.268293
#
#
# Fraud likelihood for auto_model:
# fraud_reported         0         1
# auto_model
# 3 Series        0.900000  0.100000
# 92x             0.625000  0.375000
# 93              0.769231  0.230769
# 95              0.850000  0.150000
# A3              0.619048  0.380952
# A5              0.631579  0.368421
# Accord          0.700000  0.300000
# C300            0.692308  0.307692
# CRV             0.846154  0.153846
# Camry           0.857143  0.142857
# Civic           0.571429  0.428571
# Corolla         0.750000  0.250000
# E400            0.785714  0.214286
# Escape          0.722222  0.277778
# F150            0.722222  0.277778
# Forrestor       0.736842  0.263158
# Fusion          0.692308  0.307692
# Grand Cherokee  0.705882  0.294118
# Highlander      0.692308  0.307692
# Impreza         0.615385  0.384615
# Jetta           0.708333  0.291667
# Legacy          0.850000  0.150000
# M5              0.571429  0.428571
# MDX             0.760000  0.240000
# ML350           0.545455  0.454545
# Malibu          0.866667  0.133333
# Maxima          0.733333  0.266667
# Neon            0.869565  0.130435
# Passat          0.764706  0.235294
# Pathfinder      0.789474  0.210526
# RAM             0.687500  0.312500
# RSX             0.875000  0.125000
# Silverado       0.600000  0.400000
# TL              0.777778  0.222222
# Tahoe           0.583333  0.416667
# Ultima          0.933333  0.066667
# Wrangler        0.800000  0.200000
# X5              0.636364  0.363636
# X6              0.562500  0.437500

# %%
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.barplot(x=X_train[col], y=y_train.replace({'Y': 1, 'N': 0}))
    plt.xticks(rotation=90)
    plt.title(f"Fraud Likelihood by {col}")
    plt.ylabel("Fraud Probability")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
def plot_numerical_feature_relationship(df, numerical_cols, target_col='fraud_reported'):

    df[target_col] = df[target_col].replace({'Y': 1, 'N': 0})  # Convert target variable to numeric

    for col in numerical_cols:
        plt.figure(figsize=(8, 5))
        sns.boxplot(x=df[target_col], y=df[col])
        plt.title(f"Fraud Impact on {col}")
        plt.xlabel("Fraud Reported (0 = No, 1 = Yes)")
        plt.ylabel(col)
        plt.show()

# Identify numerical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns

# Visualize impact of numerical features on fraud
plot_numerical_feature_relationship(pd.concat([X_train, y_train], axis=1), numerical_cols)

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
# Apply RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# Check class distribution after resampling
print("Class distribution before resampling:\n", y_train.value_counts())
print("Class distribution after resampling:\n", y_train_resampled.value_counts())
# This step helps ensure that the minority class (fraudulent claims) is as represented as the majority class.
# Out:
# Class distribution before resampling:
#  fraud_reported
# 0    466
# 1    169
# Name: count, dtype: int64
# Class distribution after resampling:
#  fraud_reported
# 0    466
# 1    466
# Name: count, dtype: int64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data

# Extract the day of the week from the incident date as fraud could vary by weekday.
X_train_resampled['incident_day_of_week'] = X_train_resampled['incident_date'].dt.dayofweek
X_test['incident_day_of_week'] = X_test['incident_date'].dt.dayofweek

# Create an interaction feature between total_claim_amount and policy_deductable.
# Adding a small constant to avoid division by zero.
X_train_resampled['claim_to_deductible_ratio'] = X_train_resampled['total_claim_amount'] / (X_train_resampled['policy_deductable'] + 1e-5)
X_test['claim_to_deductible_ratio'] = X_test['total_claim_amount'] / (X_test['policy_deductable'] + 1e-5)

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
def drop_redundant_by_uniqueness(df, uniqueness_threshold=0.95):    
    cols_to_drop = []
    for col in df.columns:
        unique_ratio = df[col].nunique() / len(df)
        if unique_ratio > uniqueness_threshold:
            cols_to_drop.append(col)
    return df.drop(columns=cols_to_drop), cols_to_drop

# Apply the function on the resampled training data.
X_train_resampled, dropped_train_uniques = drop_redundant_by_uniqueness(X_train_resampled, uniqueness_threshold=0.95)
print("Dropped columns from training data due to high uniqueness:", dropped_train_uniques)



# Also drop these columns from the validation set if they exist.
#X_train = X_train.drop(columns=dropped_train_uniques, errors='ignore') - To be removed
X_test = X_test.drop(columns=dropped_train_uniques, errors='ignore')
# Out:
# Dropped columns from training data due to high uniqueness: []

# %%
# Check the data
print(X_train.shape)
print(X_train_resampled.shape)
# Out:
# (635, 33)
# (932, 33)

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
# Identify categorical columns in the training dataset
categorical_cols = X_train_resampled.select_dtypes(include=['object']).columns
print("Categorical features:", categorical_cols)
# Out:
# Categorical features: Index(['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'property_damage', 'police_report_available', 'auto_make',
#        'auto_model'],
#       dtype='object')

# %%
# Function to group rare categories into "Other"
def combine_low_frequency_categories(df, categorical_cols, threshold=0.02):
    for col in categorical_cols:
        category_counts = df[col].value_counts(normalize=True)  # Get category percentages
        rare_categories = category_counts[category_counts < threshold].index  # Identify rare ones
        df[col] = df[col].replace(rare_categories, "Other")  # Group as "Other"
    
    return df

# Apply function to training and validation sets
X_train_resampled = combine_low_frequency_categories(X_train_resampled, categorical_cols)
X_test = combine_low_frequency_categories(X_test, categorical_cols)

# %%
education_mapping = {
    "High School": "Secondary",
    "College": "Tertiary",
    "Masters": "Higher Education",
    "PhD": "Higher Education",
    "Other": "Other"
}

X_train_resampled["insured_education_level"] = X_train_resampled["insured_education_level"].map(education_mapping)
X_test["insured_education_level"] = X_test["insured_education_level"].map(education_mapping)

incident_mapping = {
    "Multi-vehicle Collision": "Collision",
    "Single Vehicle Collision": "Collision",
    "Theft": "Crime",
    "Vandalism": "Crime"
}

X_train_resampled["incident_type"] = X_train_resampled["incident_type"].map(incident_mapping)
X_test["incident_type"] = X_test["incident_type"].map(incident_mapping)

# %%
# Print unique categories post-grouping
for col in categorical_cols:
    print(f"Unique values in {col} after grouping:", X_train_resampled[col].unique())
# Out:
# Unique values in policy_state after grouping: ['OH' 'IL' 'IN']
# Unique values in policy_csl after grouping: ['250/500' '100/300' '500/1000']
# Unique values in insured_sex after grouping: ['MALE' 'FEMALE']
# Unique values in insured_education_level after grouping: ['Secondary' nan 'Higher Education' 'Tertiary']
# Unique values in insured_occupation after grouping: ['protective-serv' 'adm-clerical' 'exec-managerial' 'craft-repair'
#  'priv-house-serv' 'handlers-cleaners' 'transport-moving' 'tech-support'
#  'farming-fishing' 'other-service' 'armed-forces' 'prof-specialty'
#  'machine-op-inspct' 'sales']
# Unique values in insured_hobbies after grouping: ['polo' 'movies' 'skydiving' 'cross-fit' 'chess' 'kayaking' 'camping'
#  'video-games' 'paintball' 'bungie-jumping' 'basketball' 'exercise'
#  'reading' 'dancing' 'yachting' 'sleeping' 'hiking' 'board-games' 'golf'
#  'base-jumping']
# Unique values in insured_relationship after grouping: ['other-relative' 'wife' 'husband' 'unmarried' 'own-child' 'not-in-family']
# Unique values in incident_type after grouping: ['Collision' nan]
# Unique values in collision_type after grouping: ['Front Collision' 'Rear Collision' 'Side Collision' nan]
# Unique values in incident_severity after grouping: ['Minor Damage' 'Total Loss' 'Major Damage' 'Trivial Damage']
# Unique values in authorities_contacted after grouping: ['Police' 'Other' 'Ambulance' 'Fire']
# Unique values in incident_state after grouping: ['NY' 'VA' 'WV' 'NC' 'SC' 'PA' 'OH']
# Unique values in incident_city after grouping: ['Northbrook' 'Riverwood' 'Springfield' 'Columbus' 'Arlington' 'Hillsdale'
#  'Northbend']
# Unique values in property_damage after grouping: ['NO' 'YES']
# Unique values in police_report_available after grouping: ['NO' 'YES']
# Unique values in auto_make after grouping: ['Honda' 'Volkswagen' 'Mercedes' 'Audi' 'Toyota' 'Nissan' 'Jeep' 'Dodge'
#  'BMW' 'Chevrolet' 'Ford' 'Accura' 'Saab' 'Suburu']
# Unique values in auto_model after grouping: ['Other' 'Jetta' 'A5' 'Highlander' 'Grand Cherokee' 'Neon' 'Malibu'
#  'Escape' 'MDX' '95' 'Corolla' 'Silverado' 'F150' '92x' 'Pathfinder'
#  'Camry' 'E400' 'Forrestor' 'Legacy' 'TL' 'Civic' 'RAM' 'Fusion' 'Tahoe'
#  'Wrangler' 'X6' 'A3' 'Passat' 'Impreza' '93']

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
categorical_cols = X_train_resampled.select_dtypes(include=['object']).columns
print("Categorical features:", categorical_cols)
# Out:
# Categorical features: Index(['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'property_damage', 'police_report_available', 'auto_make',
#        'auto_model'],
#       dtype='object')

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train_res_encoded = pd.get_dummies(X_train_resampled, columns=categorical_cols, drop_first=True)

print("Shape after encoding training data:", X_train_res_encoded.shape)
# Out:
# Shape after encoding training data: (932, 124)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_test_encoded = pd.get_dummies(X_test, columns=categorical_cols, drop_first=True)

# Ensure validation set has same columns as training set
missing_cols = set(X_train_res_encoded.columns) - set(X_test_encoded.columns)
for col in missing_cols:
    X_test_encoded[col] = 0  # Add missing columns with default value

# Align the columns in both datasets
X_test_encoded = X_test_encoded[X_train_res_encoded.columns]

print("Shape after encoding validation data:", X_test_encoded.shape)
# Out:
# Shape after encoding validation data: (273, 124)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
# Encode dependent variable (target)
y_train_res_encoded = y_train_resampled.replace({'Y': 1, 'N': 0})
print("Encoded target feature values:", y_train_res_encoded.unique())

# Create dummy variable for dependent feature in validation data
y_test_encoded = y_test.replace({'Y': 1, 'N': 0})
# Out:
# Encoded target feature values: [0 1]

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# Scale the numeric features present in the training data
# Identify numerical columns
numerical_cols = X_train_res_encoded.select_dtypes(include=['int64', 'float64']).columns
print("Numerical features:", numerical_cols)
# Scale the numeric features present in the validation data
# Initialize scaler
scaler = StandardScaler()

X_train_remaining = X_train_res_encoded.drop(columns=numerical_cols)
X_test_remaining = X_test_encoded.drop(columns=numerical_cols)

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train_res_encoded[numerical_cols])


# Convert back to DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=numerical_cols, index=X_train_res_encoded.index)
X_train_scaled = pd.concat([X_train_remaining, X_train_scaled], axis=1)
# Out:
# Numerical features: Index(['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')

# %%
# Transform the validation data using the same scaler
X_test_scaled = scaler.transform(X_test_encoded[numerical_cols])

# Convert back to DataFrame
X_test_scaled = pd.DataFrame(X_test_scaled, columns=numerical_cols, index=X_test_encoded.index)
X_test_scaled = pd.concat([X_test_remaining, X_test_scaled], axis=1)

# %%
print("Scaled training data shape:", X_train_scaled.shape)
print("Scaled validation data shape:", X_test_scaled.shape)
# Out:
# Scaled training data shape: (932, 124)
# Scaled validation data shape: (273, 124)

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

# %%
datetime_cols = X_train_scaled.select_dtypes(include=['datetime64']).columns
X_train_scaled = X_train_scaled.drop(columns=datetime_cols)
X_test_scaled = X_test_scaled.drop(columns=datetime_cols)

# %%
X_train_scaled = X_train_scaled.astype(float)
X_test_scaled = X_test_scaled.astype(float)

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Apply RFECV to identify the most relevant features

# Initialize the Logistic Regression model
log_reg =  LogisticRegression(penalty='l2', solver='liblinear', max_iter=500, random_state=42)

# Initialize RFECV (Recursive Feature Elimination with Cross-Validation)
rfecv = RFECV(
    estimator=log_reg,
    step=1,
    cv=StratifiedKFold(n_splits=5),
    scoring="roc_auc"
)

# Fit RFECV on the scaled training data
rfecv.fit(X_train_scaled, y_train_res_encoded)


# Select relevant features
X_train_selected = rfecv.transform(X_train_scaled)
X_test_selected = rfecv.transform(X_test_scaled)

print(f"Optimal Number of Features: {rfecv.n_features_}")
print(f"Selected Features: {X_train_scaled.columns[rfecv.support_]}")
# Out:
# Optimal Number of Features: 26
# Selected Features: Index(['insured_occupation_exec-managerial',
#        'insured_occupation_other-service', 'insured_hobbies_basketball',
#        'insured_hobbies_board-games', 'insured_hobbies_camping',
#        'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'insured_hobbies_dancing', 'insured_hobbies_exercise',
#        'insured_hobbies_golf', 'insured_hobbies_sleeping',
#        'insured_hobbies_video-games', 'insured_hobbies_yachting',
#        'collision_type_Rear Collision', 'incident_severity_Minor Damage',
#        'incident_severity_Total Loss', 'incident_severity_Trivial Damage',
#        'incident_state_WV', 'auto_model_Camry', 'auto_model_Civic',
#        'auto_model_Grand Cherokee', 'auto_model_Legacy', 'auto_model_Neon',
#        'auto_model_Other', 'auto_model_Wrangler', 'auto_model_X6'],
#       dtype='object')

# %%
plt.plot(range(1, len(rfecv.cv_results_["mean_test_score"]) + 1), rfecv.cv_results_["mean_test_score"], marker='o')
plt.xlabel("Number of Features")
plt.ylabel("Model Score (ROC-AUC)")
plt.title("RFECV Feature Selection Performance")
plt.show()

# %%
# Display the features ranking by RFECV in a DataFrame
print(f"Optimal Number of Features: {rfecv.n_features_}")
selected_features = X_train_scaled.columns[rfecv.support_]
print("Selected Features:", selected_features.tolist())
# Out:
# Optimal Number of Features: 26
# Selected Features: ['insured_occupation_exec-managerial', 'insured_occupation_other-service', 'insured_hobbies_basketball', 'insured_hobbies_board-games', 'insured_hobbies_camping', 'insured_hobbies_chess', 'insured_hobbies_cross-fit', 'insured_hobbies_dancing', 'insured_hobbies_exercise', 'insured_hobbies_golf', 'insured_hobbies_sleeping', 'insured_hobbies_video-games', 'insured_hobbies_yachting', 'collision_type_Rear Collision', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage', 'incident_state_WV', 'auto_model_Camry', 'auto_model_Civic', 'auto_model_Grand Cherokee', 'auto_model_Legacy', 'auto_model_Neon', 'auto_model_Other', 'auto_model_Wrangler', 'auto_model_X6']

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = selected_features
col
# Out:
# Index(['insured_occupation_exec-managerial',
#        'insured_occupation_other-service', 'insured_hobbies_basketball',
#        'insured_hobbies_board-games', 'insured_hobbies_camping',
#        'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'insured_hobbies_dancing', 'insured_hobbies_exercise',
#        'insured_hobbies_golf', 'insured_hobbies_sleeping',
#        'insured_hobbies_video-games', 'insured_hobbies_yachting',
#        'collision_type_Rear Collision', 'incident_severity_Minor Damage',
#        'incident_severity_Total Loss', 'incident_severity_Trivial Damage',
#        'incident_state_WV', 'auto_model_Camry', 'auto_model_Civic',
#        'auto_model_Grand Cherokee', 'auto_model_Legacy', 'auto_model_Neon',
#        'auto_model_Other', 'auto_model_Wrangler', 'auto_model_X6'],
#       dtype='object')

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
# Select only the columns selected by RFECV
X_train_final = X_train_scaled[col]
X_test_final = X_test_scaled[col]

print("Final feature set shape (Training):", X_train_final.shape)
print("Final feature set shape (Validation):", X_test_final.shape)
# Out:
# Final feature set shape (Training): (932, 26)
# Final feature set shape (Validation): (273, 26)

# %%
# Import statsmodels and add constant
import statsmodels.api as sm

# Select only the columns chosen by RFECV
X_train_final = sm.add_constant(X_train_final)  # Add a constant for regression
X_test_final = sm.add_constant(X_test_final)  # Ensure consistency in validation set

# Check the data
print("Training data shape:", X_train_final.shape)
print("Validation data shape:", X_test_final.shape)
# Out:
# Training data shape: (932, 27)
# Validation data shape: (273, 27)

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
# Fit a logistic Regression model on X_train after adding a constant and output the summary
def fit_logistic_regression(X_train, y_train):  
    log_model = sm.Logit(y_train, X_train)  # Define model
    log_model_fit = log_model.fit()  # Fit model
    return log_model_fit  # Return model summary

# Let us use this function:
log_model_fit = fit_logistic_regression(X_train_final, y_train_res_encoded)
print(log_model_fit.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.332930
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  932
# Model:                          Logit   Df Residuals:                      905
# Method:                           MLE   Df Model:                           26
# Date:                Wed, 13 Aug 2025   Pseudo R-squ.:                  0.5197
# Time:                        21:59:37   Log-Likelihood:                -310.29
# converged:                       True   LL-Null:                       -646.01
# Covariance Type:            nonrobust   LLR p-value:                6.997e-125
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.9542      0.231      8.463      0.000       1.502       2.407
# insured_occupation_exec-managerial     1.1405      0.381      2.992      0.003       0.394       1.888
# insured_occupation_other-service      -0.7947      0.429     -1.851      0.064      -1.636       0.047
# insured_hobbies_basketball            -0.8126      0.570     -1.426      0.154      -1.930       0.304
# insured_hobbies_board-games            0.7618      0.452      1.684      0.092      -0.125       1.649
# insured_hobbies_camping               -2.1282      0.547     -3.889      0.000      -3.201      -1.056
# insured_hobbies_chess                  4.7749      0.539      8.854      0.000       3.718       5.832
# insured_hobbies_cross-fit              4.1459      0.554      7.477      0.000       3.059       5.233
# insured_hobbies_dancing               -1.7245      0.733     -2.354      0.019      -3.161      -0.288
# insured_hobbies_exercise              -1.0806      0.479     -2.255      0.024      -2.020      -0.141
# insured_hobbies_golf                  -1.5970      0.609     -2.623      0.009      -2.790      -0.404
# insured_hobbies_sleeping              -1.4260      0.560     -2.546      0.011      -2.524      -0.328
# insured_hobbies_video-games            1.2762      0.434      2.940      0.003       0.425       2.127
# insured_hobbies_yachting               1.0981      0.477      2.301      0.021       0.163       2.033
# collision_type_Rear Collision          0.6768      0.236      2.866      0.004       0.214       1.140
# incident_severity_Minor Damage        -4.5768      0.342    -13.373      0.000      -5.248      -3.906
# incident_severity_Total Loss          -3.7205      0.292    -12.747      0.000      -4.293      -3.148
# incident_severity_Trivial Damage      -3.9918      0.637     -6.268      0.000      -5.240      -2.744
# incident_state_WV                     -1.0010      0.279     -3.584      0.000      -1.548      -0.454
# auto_model_Camry                      -1.8945      0.760     -2.492      0.013      -3.384      -0.405
# auto_model_Civic                       2.4577      0.612      4.015      0.000       1.258       3.658
# auto_model_Grand Cherokee              1.2829      0.637      2.013      0.044       0.034       2.532
# auto_model_Legacy                     -1.4819      0.671     -2.208      0.027      -2.797      -0.167
# auto_model_Neon                       -1.2652      0.718     -1.762      0.078      -2.673       0.142
# auto_model_Other                      -0.7525      0.306     -2.463      0.014      -1.351      -0.154
# auto_model_Wrangler                   -1.1237      0.586     -1.917      0.055      -2.273       0.025
# auto_model_X6                          0.7974      0.737      1.082      0.279      -0.647       2.242
# ======================================================================================================

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
def compute_vif(dataframe):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = dataframe.columns
    vif_data["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(dataframe.shape[1])]
    
    return vif_data

# Use the function
vif_result = compute_vif(X_train_final)
print(vif_result)
# Out:
#                                Feature       VIF
# 0                                const  4.567853
# 1   insured_occupation_exec-managerial  1.086223
# 2     insured_occupation_other-service  1.031555
# 3           insured_hobbies_basketball  1.047463
# 4          insured_hobbies_board-games  1.105014
# 5              insured_hobbies_camping  1.080011
# 6                insured_hobbies_chess  1.105827
# 7            insured_hobbies_cross-fit  1.125725
# 8              insured_hobbies_dancing  1.063808
# 9             insured_hobbies_exercise  1.084774
# 10                insured_hobbies_golf  1.067997
# 11            insured_hobbies_sleeping  1.035842
# 12         insured_hobbies_video-games  1.081605
# 13            insured_hobbies_yachting  1.108601
# 14       collision_type_Rear Collision  1.078003
# 15      incident_severity_Minor Damage  1.277689
# 16        incident_severity_Total Loss  1.302666
# 17    incident_severity_Trivial Damage  1.134997
# 18                   incident_state_WV  1.067017
# 19                    auto_model_Camry  1.045985
# 20                    auto_model_Civic  1.082186
# 21           auto_model_Grand Cherokee  1.052817
# 22                   auto_model_Legacy  1.031410
# 23                     auto_model_Neon  1.054517
# 24                    auto_model_Other  1.073757
# 25                 auto_model_Wrangler  1.040896
# 26                       auto_model_X6  1.029346

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
def analyze_logistic_regression(X_train, y_train):
   
    # Fit Logistic Regression Model
    log_model_fit = fit_logistic_regression(X_train, y_train)
    
    # Compute VIF 
    vif_data = compute_vif(X_train)

    return log_model_fit, vif_data

# %%
log_model_fit, vif_result = analyze_logistic_regression(X_train_final, y_train_res_encoded)
print(log_model_fit.summary())
print(vif_result)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.332930
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  932
# Model:                          Logit   Df Residuals:                      905
# Method:                           MLE   Df Model:                           26
# Date:                Wed, 13 Aug 2025   Pseudo R-squ.:                  0.5197
# Time:                        22:01:14   Log-Likelihood:                -310.29
# converged:                       True   LL-Null:                       -646.01
# Covariance Type:            nonrobust   LLR p-value:                6.997e-125
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.9542      0.231      8.463      0.000       1.502       2.407
# insured_occupation_exec-managerial     1.1405      0.381      2.992      0.003       0.394       1.888
# insured_occupation_other-service      -0.7947      0.429     -1.851      0.064      -1.636       0.047
# insured_hobbies_basketball            -0.8126      0.570     -1.426      0.154      -1.930       0.304
# insured_hobbies_board-games            0.7618      0.452      1.684      0.092      -0.125       1.649
# insured_hobbies_camping               -2.1282      0.547     -3.889      0.000      -3.201      -1.056
# insured_hobbies_chess                  4.7749      0.539      8.854      0.000       3.718       5.832
# insured_hobbies_cross-fit              4.1459      0.554      7.477      0.000       3.059       5.233
# insured_hobbies_dancing               -1.7245      0.733     -2.354      0.019      -3.161      -0.288
# insured_hobbies_exercise              -1.0806      0.479     -2.255      0.024      -2.020      -0.141
# insured_hobbies_golf                  -1.5970      0.609     -2.623      0.009      -2.790      -0.404
# insured_hobbies_sleeping              -1.4260      0.560     -2.546      0.011      -2.524      -0.328
# insured_hobbies_video-games            1.2762      0.434      2.940      0.003       0.425       2.127
# insured_hobbies_yachting               1.0981      0.477      2.301      0.021       0.163       2.033
# collision_type_Rear Collision          0.6768      0.236      2.866      0.004       0.214       1.140
# incident_severity_Minor Damage        -4.5768      0.342    -13.373      0.000      -5.248      -3.906
# incident_severity_Total Loss          -3.7205      0.292    -12.747      0.000      -4.293      -3.148
# incident_severity_Trivial Damage      -3.9918      0.637     -6.268      0.000      -5.240      -2.744
# incident_state_WV                     -1.0010      0.279     -3.584      0.000      -1.548      -0.454
# auto_model_Camry                      -1.8945      0.760     -2.492      0.013      -3.384      -0.405
# auto_model_Civic                       2.4577      0.612      4.015      0.000       1.258       3.658
# auto_model_Grand Cherokee              1.2829      0.637      2.013      0.044       0.034       2.532
# auto_model_Legacy                     -1.4819      0.671     -2.208      0.027      -2.797      -0.167
# auto_model_Neon                       -1.2652      0.718     -1.762      0.078      -2.673       0.142
# auto_model_Other                      -0.7525      0.306     -2.463      0.014      -1.351      -0.154
# auto_model_Wrangler                   -1.1237      0.586     -1.917      0.055      -2.273       0.025
# auto_model_X6                          0.7974      0.737      1.082      0.279      -0.647       2.242
# ======================================================================================================
#                                Feature       VIF
# 0                                const  4.567853
# 1   insured_occupation_exec-managerial  1.086223
# 2     insured_occupation_other-service  1.031555
# 3           insured_hobbies_basketball  1.047463
# 4          insured_hobbies_board-games  1.105014
# 5              insured_hobbies_camping  1.080011
# 6                insured_hobbies_chess  1.105827
# 7            insured_hobbies_cross-fit  1.125725
# 8              insured_hobbies_dancing  1.063808
# 9             insured_hobbies_exercise  1.084774
# 10                insured_hobbies_golf  1.067997
# 11            insured_hobbies_sleeping  1.035842
# 12         insured_hobbies_video-games  1.081605
# 13            insured_hobbies_yachting  1.108601
# 14       collision_type_Rear Collision  1.078003
# 15      incident_severity_Minor Damage  1.277689
# 16        incident_severity_Total Loss  1.302666
# 17    incident_severity_Trivial Damage  1.134997
# 18                   incident_state_WV  1.067017
# 19                    auto_model_Camry  1.045985
# 20                    auto_model_Civic  1.082186
# 21           auto_model_Grand Cherokee  1.052817
# 22                   auto_model_Legacy  1.031410
# 23                     auto_model_Neon  1.054517
# 24                    auto_model_Other  1.073757
# 25                 auto_model_Wrangler  1.040896
# 26                       auto_model_X6  1.029346

# %%
log_model_fit, vif_result = analyze_logistic_regression(X_train_final, y_train_res_encoded)
print(log_model_fit.summary())
print(vif_result)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.332930
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  932
# Model:                          Logit   Df Residuals:                      905
# Method:                           MLE   Df Model:                           26
# Date:                Wed, 13 Aug 2025   Pseudo R-squ.:                  0.5197
# Time:                        22:02:03   Log-Likelihood:                -310.29
# converged:                       True   LL-Null:                       -646.01
# Covariance Type:            nonrobust   LLR p-value:                6.997e-125
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.9542      0.231      8.463      0.000       1.502       2.407
# insured_occupation_exec-managerial     1.1405      0.381      2.992      0.003       0.394       1.888
# insured_occupation_other-service      -0.7947      0.429     -1.851      0.064      -1.636       0.047
# insured_hobbies_basketball            -0.8126      0.570     -1.426      0.154      -1.930       0.304
# insured_hobbies_board-games            0.7618      0.452      1.684      0.092      -0.125       1.649
# insured_hobbies_camping               -2.1282      0.547     -3.889      0.000      -3.201      -1.056
# insured_hobbies_chess                  4.7749      0.539      8.854      0.000       3.718       5.832
# insured_hobbies_cross-fit              4.1459      0.554      7.477      0.000       3.059       5.233
# insured_hobbies_dancing               -1.7245      0.733     -2.354      0.019      -3.161      -0.288
# insured_hobbies_exercise              -1.0806      0.479     -2.255      0.024      -2.020      -0.141
# insured_hobbies_golf                  -1.5970      0.609     -2.623      0.009      -2.790      -0.404
# insured_hobbies_sleeping              -1.4260      0.560     -2.546      0.011      -2.524      -0.328
# insured_hobbies_video-games            1.2762      0.434      2.940      0.003       0.425       2.127
# insured_hobbies_yachting               1.0981      0.477      2.301      0.021       0.163       2.033
# collision_type_Rear Collision          0.6768      0.236      2.866      0.004       0.214       1.140
# incident_severity_Minor Damage        -4.5768      0.342    -13.373      0.000      -5.248      -3.906
# incident_severity_Total Loss          -3.7205      0.292    -12.747      0.000      -4.293      -3.148
# incident_severity_Trivial Damage      -3.9918      0.637     -6.268      0.000      -5.240      -2.744
# incident_state_WV                     -1.0010      0.279     -3.584      0.000      -1.548      -0.454
# auto_model_Camry                      -1.8945      0.760     -2.492      0.013      -3.384      -0.405
# auto_model_Civic                       2.4577      0.612      4.015      0.000       1.258       3.658
# auto_model_Grand Cherokee              1.2829      0.637      2.013      0.044       0.034       2.532
# auto_model_Legacy                     -1.4819      0.671     -2.208      0.027      -2.797      -0.167
# auto_model_Neon                       -1.2652      0.718     -1.762      0.078      -2.673       0.142
# auto_model_Other                      -0.7525      0.306     -2.463      0.014      -1.351      -0.154
# auto_model_Wrangler                   -1.1237      0.586     -1.917      0.055      -2.273       0.025
# auto_model_X6                          0.7974      0.737      1.082      0.279      -0.647       2.242
# ======================================================================================================
#                                Feature       VIF
# 0                                const  4.567853
# 1   insured_occupation_exec-managerial  1.086223
# 2     insured_occupation_other-service  1.031555
# 3           insured_hobbies_basketball  1.047463
# 4          insured_hobbies_board-games  1.105014
# 5              insured_hobbies_camping  1.080011
# 6                insured_hobbies_chess  1.105827
# 7            insured_hobbies_cross-fit  1.125725
# 8              insured_hobbies_dancing  1.063808
# 9             insured_hobbies_exercise  1.084774
# 10                insured_hobbies_golf  1.067997
# 11            insured_hobbies_sleeping  1.035842
# 12         insured_hobbies_video-games  1.081605
# 13            insured_hobbies_yachting  1.108601
# 14       collision_type_Rear Collision  1.078003
# 15      incident_severity_Minor Damage  1.277689
# 16        incident_severity_Total Loss  1.302666
# 17    incident_severity_Trivial Damage  1.134997
# 18                   incident_state_WV  1.067017
# 19                    auto_model_Camry  1.045985
# 20                    auto_model_Civic  1.082186
# 21           auto_model_Grand Cherokee  1.052817
# 22                   auto_model_Legacy  1.031410
# 23                     auto_model_Neon  1.054517
# 24                    auto_model_Other  1.073757
# 25                 auto_model_Wrangler  1.040896
# 26                       auto_model_X6  1.029346

# %%
X_train_final = X_train_final.drop(columns=["insured_hobbies_basketball"]) 
X_test_final = X_test_final.drop(columns=["insured_hobbies_basketball"])
log_model_fit, vif_result = analyze_logistic_regression(X_train_final, y_train_res_encoded)
print(log_model_fit.summary())
print(vif_result)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.334014
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  932
# Model:                          Logit   Df Residuals:                      906
# Method:                           MLE   Df Model:                           25
# Date:                Wed, 13 Aug 2025   Pseudo R-squ.:                  0.5181
# Time:                        22:02:26   Log-Likelihood:                -311.30
# converged:                       True   LL-Null:                       -646.01
# Covariance Type:            nonrobust   LLR p-value:                3.539e-125
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.8854      0.223      8.437      0.000       1.447       2.323
# insured_occupation_exec-managerial     1.1220      0.382      2.938      0.003       0.373       1.871
# insured_occupation_other-service      -0.7454      0.425     -1.754      0.080      -1.579       0.088
# insured_hobbies_board-games            0.8225      0.450      1.826      0.068      -0.060       1.705
# insured_hobbies_camping               -2.0644      0.544     -3.794      0.000      -3.131      -0.998
# insured_hobbies_chess                  4.8325      0.539      8.971      0.000       3.777       5.888
# insured_hobbies_cross-fit              4.2014      0.554      7.586      0.000       3.116       5.287
# insured_hobbies_dancing               -1.6770      0.730     -2.297      0.022      -3.108      -0.246
# insured_hobbies_exercise              -1.0152      0.476     -2.131      0.033      -1.949      -0.081
# insured_hobbies_golf                  -1.5398      0.606     -2.541      0.011      -2.728      -0.352
# insured_hobbies_sleeping              -1.3673      0.558     -2.452      0.014      -2.460      -0.275
# insured_hobbies_video-games            1.3285      0.433      3.068      0.002       0.480       2.177
# insured_hobbies_yachting               1.1466      0.477      2.406      0.016       0.213       2.081
# collision_type_Rear Collision          0.6879      0.235      2.924      0.003       0.227       1.149
# incident_severity_Minor Damage        -4.5570      0.341    -13.357      0.000      -5.226      -3.888
# incident_severity_Total Loss          -3.7120      0.290    -12.809      0.000      -4.280      -3.144
# incident_severity_Trivial Damage      -3.9759      0.636     -6.250      0.000      -5.223      -2.729
# incident_state_WV                     -1.0119      0.280     -3.610      0.000      -1.561      -0.462
# auto_model_Camry                      -1.8665      0.757     -2.464      0.014      -3.351      -0.382
# auto_model_Civic                       2.4708      0.613      4.034      0.000       1.270       3.671
# auto_model_Grand Cherokee              1.3040      0.641      2.035      0.042       0.048       2.560
# auto_model_Legacy                     -1.4410      0.670     -2.151      0.031      -2.754      -0.128
# auto_model_Neon                       -1.2603      0.715     -1.763      0.078      -2.661       0.141
# auto_model_Other                      -0.7386      0.304     -2.428      0.015      -1.335      -0.142
# auto_model_Wrangler                   -1.2094      0.588     -2.056      0.040      -2.362      -0.057
# auto_model_X6                          0.8313      0.734      1.133      0.257      -0.606       2.269
# ======================================================================================================
#                                Feature       VIF
# 0                                const  4.448959
# 1   insured_occupation_exec-managerial  1.085633
# 2     insured_occupation_other-service  1.031432
# 3          insured_hobbies_board-games  1.097790
# 4              insured_hobbies_camping  1.074409
# 5                insured_hobbies_chess  1.094963
# 6            insured_hobbies_cross-fit  1.117637
# 7              insured_hobbies_dancing  1.059321
# 8             insured_hobbies_exercise  1.076773
# 9                 insured_hobbies_golf  1.063000
# 10            insured_hobbies_sleeping  1.031316
# 11         insured_hobbies_video-games  1.074595
# 12            insured_hobbies_yachting  1.102954
# 13       collision_type_Rear Collision  1.076452
# 14      incident_severity_Minor Damage  1.277655
# 15        incident_severity_Total Loss  1.298649
# 16    incident_severity_Trivial Damage  1.134993
# 17                   incident_state_WV  1.066830
# 18                    auto_model_Camry  1.045655
# 19                    auto_model_Civic  1.081691
# 20           auto_model_Grand Cherokee  1.052500
# 21                   auto_model_Legacy  1.029998
# 22                     auto_model_Neon  1.054370
# 23                    auto_model_Other  1.073696
# 24                 auto_model_Wrangler  1.036552
# 25                       auto_model_X6  1.028216

# %%
X_train_final = X_train_final.drop(columns=["insured_occupation_other-service"]) 
X_test_final = X_test_final.drop(columns=["insured_occupation_other-service"])
log_model_fit, vif_result = analyze_logistic_regression(X_train_final, y_train_res_encoded)
print(log_model_fit.summary())
print(vif_result)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.335635
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  932
# Model:                          Logit   Df Residuals:                      907
# Method:                           MLE   Df Model:                           24
# Date:                Wed, 13 Aug 2025   Pseudo R-squ.:                  0.5158
# Time:                        22:02:49   Log-Likelihood:                -312.81
# converged:                       True   LL-Null:                       -646.01
# Covariance Type:            nonrobust   LLR p-value:                2.855e-125
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.7894      0.213      8.407      0.000       1.372       2.207
# insured_occupation_exec-managerial     1.1627      0.380      3.062      0.002       0.418       1.907
# insured_hobbies_board-games            0.9131      0.443      2.060      0.039       0.044       1.782
# insured_hobbies_camping               -1.9883      0.541     -3.678      0.000      -3.048      -0.929
# insured_hobbies_chess                  4.8865      0.541      9.033      0.000       3.826       5.947
# insured_hobbies_cross-fit              4.2598      0.554      7.683      0.000       3.173       5.346
# insured_hobbies_dancing               -1.6332      0.723     -2.259      0.024      -3.050      -0.216
# insured_hobbies_exercise              -0.9529      0.475     -2.005      0.045      -1.885      -0.021
# insured_hobbies_golf                  -1.4837      0.599     -2.476      0.013      -2.658      -0.309
# insured_hobbies_sleeping              -1.2892      0.551     -2.339      0.019      -2.369      -0.209
# insured_hobbies_video-games            1.3782      0.433      3.182      0.001       0.529       2.227
# insured_hobbies_yachting               1.1654      0.474      2.458      0.014       0.236       2.095
# collision_type_Rear Collision          0.6912      0.236      2.935      0.003       0.230       1.153
# incident_severity_Minor Damage        -4.5185      0.339    -13.337      0.000      -5.183      -3.855
# incident_severity_Total Loss          -3.6639      0.286    -12.806      0.000      -4.225      -3.103
# incident_severity_Trivial Damage      -3.9212      0.635     -6.179      0.000      -5.165      -2.677
# incident_state_WV                     -1.0711      0.280     -3.825      0.000      -1.620      -0.522
# auto_model_Camry                      -1.8108      0.755     -2.398      0.016      -3.291      -0.331
# auto_model_Civic                       2.4990      0.612      4.083      0.000       1.300       3.699
# auto_model_Grand Cherokee              1.2767      0.654      1.952      0.051      -0.005       2.559
# auto_model_Legacy                     -1.3985      0.662     -2.112      0.035      -2.696      -0.101
# auto_model_Neon                       -1.2433      0.713     -1.743      0.081      -2.642       0.155
# auto_model_Other                      -0.7424      0.303     -2.449      0.014      -1.336      -0.148
# auto_model_Wrangler                   -1.2035      0.579     -2.079      0.038      -2.338      -0.069
# auto_model_X6                          0.8403      0.733      1.147      0.251      -0.596       2.276
# ======================================================================================================
#                                Feature       VIF
# 0                                const  4.323667
# 1   insured_occupation_exec-managerial  1.076843
# 2          insured_hobbies_board-games  1.089615
# 3              insured_hobbies_camping  1.072552
# 4                insured_hobbies_chess  1.093715
# 5            insured_hobbies_cross-fit  1.115741
# 6              insured_hobbies_dancing  1.059147
# 7             insured_hobbies_exercise  1.076510
# 8                 insured_hobbies_golf  1.062367
# 9             insured_hobbies_sleeping  1.031226
# 10         insured_hobbies_video-games  1.072007
# 11            insured_hobbies_yachting  1.102609
# 12       collision_type_Rear Collision  1.075024
# 13      incident_severity_Minor Damage  1.277213
# 14        incident_severity_Total Loss  1.297967
# 15    incident_severity_Trivial Damage  1.134907
# 16                   incident_state_WV  1.063194
# 17                    auto_model_Camry  1.045620
# 18                    auto_model_Civic  1.080904
# 19           auto_model_Grand Cherokee  1.050286
# 20                   auto_model_Legacy  1.029962
# 21                     auto_model_Neon  1.053308
# 22                    auto_model_Other  1.073602
# 23                 auto_model_Wrangler  1.036283
# 24                       auto_model_X6  1.028216

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
y_train_pred_prob = log_model_fit.predict(X_train_final)
# Reshape it into an array
y_train_pred_prob = y_train_pred_prob.values.reshape(-1, 1)

print("Predicted probabilities:\n", y_train_pred_prob[:10])
# Out:
# Predicted probabilities:
#  [[0.03013409]
#  [0.13302782]
#  [0.13776373]
#  [0.85046627]
#  [0.85685633]
#  [0.78822244]
#  [0.89635383]
#  [0.03013409]
#  [0.01956088]
#  [0.0249589 ]]

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model

# Create new column indicating predicted classifications based on a cutoff value of 0.5
train_results_df = pd.DataFrame({
    "Actual_Fraud": y_train_res_encoded,
    "Predicted_Probability": y_train_pred_prob.flatten(),
    "Predicted_Fraud": (y_train_pred_prob.flatten() >= 0.5).astype(int)  # 1 = Fraud, 0 = Legitimate
})
print(train_results_df.head())
# Out:
#    Actual_Fraud  Predicted_Probability  Predicted_Fraud
# 0             0               0.030134                0
# 1             0               0.133028                0
# 2             0               0.137764                0
# 3             1               0.850466                1
# 4             0               0.856856                1

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score

# Check the accuracy of the model
accuracy = accuracy_score(y_train_res_encoded, train_results_df["Predicted_Fraud"])
print(f"Model Accuracy on Training Data: {accuracy:.2f}")
# Out:
# Model Accuracy on Training Data: 0.89

# %% [markdown]
# **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix

# Generate confusion matrix
conf_matrix = confusion_matrix(y_train_res_encoded, train_results_df["Predicted_Fraud"])

print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[404  62]
#  [ 43 423]]

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = conf_matrix.ravel()

print(f"True Positives: {TP}, True Negatives: {TN}, False Positives: {FP}, False Negatives: {FN}")
# Out:
# True Positives: 423, True Negatives: 404, False Positives: 62, False Negatives: 43

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity = TP / (TP + FN)

# Calculate Specificity
specificity = TN / (TN + FP)

# Calculate Precision
precision = TP / (TP + FP)

# Calculate Recall 
recall = sensitivity

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)

print(f"Sensitivity: {sensitivity:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1_score:.2f}")
# Out:
# Sensitivity: 0.91
# Specificity: 0.87
# Precision: 0.87
# Recall: 0.91
# F1-score: 0.89

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, auc


# Define ROC function
def plot_roc_curve(y_true, y_scores):
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')  # Diagonal reference line
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()
    
    return fpr, tpr, thresholds

# %%
# Call the ROC function
fpr, tpr, thresholds_roc = plot_roc_curve(y_train_res_encoded, y_train_pred_prob.flatten())

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance

cutoff_values = np.arange(0.1, 0.91, 0.05)  # Test cutoffs from 0.1 to 0.9

performance_metrics = []

for cutoff in cutoff_values:
    y_pred_cutoff = (y_train_pred_prob.flatten() >= cutoff).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_train_res_encoded, y_pred_cutoff).ravel()
    
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn) if (tp+fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn+fp) > 0 else 0
    
    performance_metrics.append({
        'Cutoff': cutoff,
        'Accuracy': accuracy,
        'Sensitivity': sensitivity,
        'Specificity': specificity,
        'Youden_Index': sensitivity + specificity - 1  # Optimizing via Youden’s index
    })

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
metrics_df = pd.DataFrame(performance_metrics)
print(metrics_df)
# Out:
#     Cutoff  Accuracy  Sensitivity  Specificity  Youden_Index
# 0     0.10  0.767167     0.989270     0.545064      0.534335
# 1     0.15  0.836910     0.969957     0.703863      0.673820
# 2     0.20  0.847639     0.959227     0.736052      0.695279
# 3     0.25  0.864807     0.950644     0.778970      0.729614
# 4     0.30  0.874464     0.946352     0.802575      0.748927
# 5     0.35  0.887339     0.946352     0.828326      0.774678
# 6     0.40  0.887339     0.933476     0.841202      0.774678
# 7     0.45  0.891631     0.929185     0.854077      0.783262
# 8     0.50  0.887339     0.907725     0.866953      0.774678
# 9     0.55  0.880901     0.886266     0.875536      0.761803
# 10    0.60  0.881974     0.881974     0.881974      0.763948
# 11    0.65  0.875536     0.862661     0.888412      0.751073
# 12    0.70  0.865880     0.824034     0.907725      0.731760
# 13    0.75  0.827253     0.736052     0.918455      0.654506
# 14    0.80  0.809013     0.690987     0.927039      0.618026
# 15    0.85  0.791845     0.652361     0.931330      0.583691
# 16    0.90  0.670601     0.381974     0.959227      0.341202

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10, 6))
plt.plot(metrics_df['Cutoff'], metrics_df['Accuracy'], marker='o', label='Accuracy')
plt.plot(metrics_df['Cutoff'], metrics_df['Sensitivity'], marker='o', label='Sensitivity')
plt.plot(metrics_df['Cutoff'], metrics_df['Specificity'], marker='o', label='Specificity')
plt.xlabel("Probability Cutoff")
plt.ylabel("Metric Value")
plt.title("Accuracy, Sensitivity, and Specificity at Different Cutoffs")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
optimal_row = metrics_df.loc[metrics_df['Youden_Index'].idxmax()]
optimal_cutoff = optimal_row['Cutoff']
print(f"Optimal Cutoff based on Youden's index: {optimal_cutoff:.2f}")
# Out:
# Optimal Cutoff based on Youden's index: 0.45

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
train_results_df['Final_Predicted_Fraud'] = (train_results_df['Predicted_Probability'] >= optimal_cutoff).astype(int)

final_accuracy = accuracy_score(y_train_res_encoded, train_results_df['Final_Predicted_Fraud'])
print(f"Final Model Accuracy: {final_accuracy:.2f}")
# Out:
# Final Model Accuracy: 0.89

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
final_conf_matrix = confusion_matrix(y_train_res_encoded, train_results_df['Final_Predicted_Fraud'])
print("Final Confusion Matrix:\n", final_conf_matrix)
# Out:
# Final Confusion Matrix:
#  [[398  68]
#  [ 33 433]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = final_conf_matrix.ravel()
print(f"True Positives (TP): {TP}")
print(f"True Negatives (TN): {TN}")
print(f"False Positives (FP): {FP}")
print(f"False Negatives (FN): {FN}")
# Out:
# True Positives (TP): 433
# True Negatives (TN): 398
# False Positives (FP): 68
# False Negatives (FN): 33

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity_opt = TP / (TP + FN) if (TP + FN) > 0 else 0

# Calculate the specificity
specificity_opt = TN / (TN + FP) if (TN + FP) > 0 else 0

# Calculate Precision
precision_opt = TP / (TP + FP) if (TP + FP) > 0 else 0

# Calculate Recall
recall_opt = sensitivity_opt  

# Calculate F1 Score
f1_score_opt = 2 * (precision_opt * recall_opt) / (precision_opt + recall_opt) if (precision_opt + recall_opt) > 0 else 0

print(f"Sensitivity: {sensitivity_opt:.2f}")
print(f"Specificity: {specificity_opt:.2f}")
print(f"Precision: {precision_opt:.2f}")
print(f"Recall: {recall_opt:.2f}")
print(f"F1 Score: {f1_score_opt:.2f}")
# Out:
# Sensitivity: 0.93
# Specificity: 0.85
# Precision: 0.86
# Recall: 0.93
# F1 Score: 0.90

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
precision_vals, recall_vals, thresholds_pr = precision_recall_curve(y_train_res_encoded, y_train_pred_prob.flatten())

plt.figure(figsize=(8, 6))
plt.plot(recall_vals, precision_vals, marker='.', label='Precision-Recall Curve')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier 
from sklearn.metrics import classification_report, precision_score, confusion_matrix, accuracy_score, recall_score
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
model = BalancedRandomForestClassifier(n_estimators = 100, random_state = 42)

# Fit the model on training data
model.fit(X_train_scaled, y_train_res_encoded)

# Check training accuracy
train_accuracy = model.score(X_train_scaled, y_train_res_encoded)
print(f"Random Forest Training Accuracy: {train_accuracy:.2f}")
# Out:
# Random Forest Training Accuracy: 1.00

# %%
rfecv = RFECV(estimator=model, step=1, cv=5, scoring="accuracy")
rfecv.fit(X_train_scaled, y_train_res_encoded)
# Check training accuracy
print(f"Optimal number of features: {rfecv.n_features_}")
print(f"Selected features: {X_train_scaled.columns[rfecv.support_]}")
# Out:
# Optimal number of features: 117
# Selected features: Index(['policy_state_IN', 'policy_state_OH', 'policy_csl_250/500',
#        'policy_csl_500/1000', 'insured_sex_MALE',
#        'insured_education_level_Secondary', 'insured_education_level_Tertiary',
#        'insured_occupation_armed-forces', 'insured_occupation_craft-repair',
#        'insured_occupation_exec-managerial',
#        ...
#        'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object', length=117)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
feature_importances = model.feature_importances_

# Create a DataFrame to visualise the importance scores

importance_df = pd.DataFrame({
    "Feature": X_train_scaled.columns,
    "Importance": feature_importances
}).sort_values(by="Importance", ascending=False)

print("Feature Importance:\n", importance_df.head(58))

# Plot feature importance
plt.figure(figsize=(10, 6))
plt.barh(importance_df["Feature"], importance_df["Importance"], color="skyblue")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance - Random Forest")
plt.gca().invert_yaxis()
plt.show()
# Out:
# Feature Importance:
#                                   Feature  Importance
# 46        incident_severity_Minor Damage    0.086528
# 47          incident_severity_Total Loss    0.060310
# 120                       property_claim    0.047599
# 121                        vehicle_claim    0.045916
# 118                   total_claim_amount    0.044730
# 119                         injury_claim    0.039802
# 24                 insured_hobbies_chess    0.036530
# 108                   months_as_customer    0.033635
# 109                                  age    0.030889
# 114             incident_hour_of_the_day    0.030665
# 122                            auto_year    0.029548
# 113                         capital-loss    0.025630
# 112                        capital-gains    0.024556
# 25             insured_hobbies_cross-fit    0.024142
# 117                            witnesses    0.020314
# 111                       umbrella_limit    0.011550
# 110                    policy_deductable    0.011095
# 115          number_of_vehicles_involved    0.011068
# 116                      bodily_injuries    0.009699
# 51          authorities_contacted_Police    0.008561
# 44         collision_type_Rear Collision    0.007846
# 57                     incident_state_WV    0.007591
# 1                        policy_state_OH    0.007222
# 4                       insured_sex_MALE    0.007131
# 65           police_report_available_YES    0.007042
# 5      insured_education_level_Secondary    0.006958
# 2                     policy_csl_250/500    0.006806
# 23               insured_hobbies_camping    0.006649
# 64                   property_damage_YES    0.006485
# 9     insured_occupation_exec-managerial    0.006420
# 45         collision_type_Side Collision    0.006188
# 0                        policy_state_IN    0.005872
# 50           authorities_contacted_Other    0.005804
# 3                    policy_csl_500/1000    0.005700
# 66                        auto_make_Audi    0.005645
# 41        insured_relationship_own-child    0.005587
# 49            authorities_contacted_Fire    0.005510
# 63             incident_city_Springfield    0.005478
# 40   insured_relationship_other-relative    0.005476
# 8        insured_occupation_craft-repair    0.005328
# 18       insured_occupation_tech-support    0.005303
# 52                     incident_state_NY    0.005303
# 26               insured_hobbies_dancing    0.005188
# 61              incident_city_Northbrook    0.005172
# 43             insured_relationship_wife    0.005168
# 59               incident_city_Hillsdale    0.005000
# 39    insured_relationship_not-in-family    0.004997
# 58                incident_city_Columbus    0.004738
# 62               incident_city_Riverwood    0.004685
# 55                     incident_state_SC    0.004643
# 60               incident_city_Northbend    0.004560
# 99                      auto_model_Other    0.004453
# 27              insured_hobbies_exercise    0.004247
# 84                      auto_model_Civic    0.004108
# 98                       auto_model_Neon    0.004048
# 56                     incident_state_VA    0.004037
# 42        insured_relationship_unmarried    0.004008
# 102                       auto_model_RAM    0.003916

# %%
# Select features with high importance scores
selected_features_rf = importance_df["Feature"].head(27).tolist() #Cut off is 0.006

# Create a new training data with only the selected features

X_train_rf = X_train_scaled[selected_features_rf]
X_test_rf = X_test_scaled[selected_features_rf]

print("Selected Features for Model Training:\n", selected_features_rf)
# Out:
# Selected Features for Model Training:
#  ['incident_severity_Minor Damage', 'incident_severity_Total Loss', 'property_claim', 'vehicle_claim', 'total_claim_amount', 'injury_claim', 'insured_hobbies_chess', 'months_as_customer', 'age', 'incident_hour_of_the_day', 'auto_year', 'capital-loss', 'capital-gains', 'insured_hobbies_cross-fit', 'witnesses', 'umbrella_limit', 'policy_deductable', 'number_of_vehicles_involved', 'bodily_injuries', 'authorities_contacted_Police', 'collision_type_Rear Collision', 'incident_state_WV', 'policy_state_OH', 'insured_sex_MALE', 'police_report_available_YES', 'insured_education_level_Secondary', 'policy_csl_250/500']

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
model.fit(X_train_rf, y_train_res_encoded)

# Get training accuracy
train_accuracy_rf = model.score(X_train_rf, y_train_res_encoded)
print(f"Training Accuracy After Feature Selection: {train_accuracy_rf:.2f}")
# Out:
# Training Accuracy After Feature Selection: 1.00

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_pred_rf = model.predict(X_train_rf)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
accuracy_rf = accuracy_score(y_train_res_encoded, y_train_pred_rf)
print(f"Model Accuracy on Training Data: {accuracy_rf:.2f}")
# Out:
# Model Accuracy on Training Data: 1.00

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
conf_matrix_rf = confusion_matrix(y_train_res_encoded, y_train_pred_rf)
print("Confusion Matrix:\n", conf_matrix_rf)
# Out:
# Confusion Matrix:
#  [[466   0]
#  [  0 466]]

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_rf, FP_rf, FN_rf, TP_rf = conf_matrix_rf.ravel()

print(f"True Positives: {TP_rf}, True Negatives: {TN_rf}, False Positives: {FP_rf}, False Negatives: {FN_rf}")
# Out:
# True Positives: 466, True Negatives: 466, False Positives: 0, False Negatives: 0

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf = TP_rf / (TP_rf + FN_rf) if (TP_rf + FN_rf) > 0 else 0

# Calculate the specificity
specificity_rf = TN_rf / (TN_rf + FP_rf) if (TN_rf + FP_rf) > 0 else 0

# Calculate Precision
precision_rf = precision_score(y_train_res_encoded, y_train_pred_rf)

# Calculate Recall
recall_rf = recall_score(y_train_res_encoded, y_train_pred_rf)

# Calculate F1 Score
f1_score_rf = 2 * (precision_rf * recall_rf) / (precision_rf + recall_rf) if (precision_rf + recall_rf) > 0 else 0

print(f"Sensitivity: {sensitivity_rf:.2f}")
print(f"Specificity: {specificity_rf:.2f}")
print(f"Precision: {precision_rf:.2f}")
print(f"Recall: {recall_rf:.2f}")
print(f"F1 Score: {f1_score_rf:.2f}")
# Out:
# Sensitivity: 1.00
# Specificity: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cv_scores_rf = cross_val_score(model, X_train_rf, y_train_res_encoded, cv=5, scoring="accuracy")

print(f"Cross-Validation Accuracy Scores: {cv_scores_rf}")
print(f"Mean CV Accuracy: {np.mean(cv_scores_rf):.2f}")
# Out:
# Cross-Validation Accuracy Scores: [0.90374332 0.88770053 0.92473118 0.91935484 0.92473118]
# Mean CV Accuracy: 0.91

# %%
y_train_pred_rf_best = model.predict_proba(X_train_scaled[selected_features_rf])[:, 1]

# %%
# Call the ROC function
fpr, tpr, thresholds_roc = plot_roc_curve(y_train_res_encoded, y_train_pred_rf_best.flatten())

# %%
# Plot precision-recall curve
precision_vals, recall_vals, thresholds_pr = precision_recall_curve(y_train_res_encoded, y_train_pred_rf_best.flatten())

plt.figure(figsize=(8, 6))
plt.plot(recall_vals, precision_vals, marker='.', label='Precision-Recall Curve')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
from sklearn.model_selection import GridSearchCV
# Use grid search to find the best hyperparamter values
param_grid = {
    'n_estimators': [50, 100,150],  # Number of trees
    'max_depth': [4,6,8,10],  # Maximum depth of trees
    'min_samples_split': [10,20,30],  # Minimum samples to split an internal node
    'min_samples_leaf': [10,20,30],  # Minimum samples at leaf node
    'max_features': ['sqrt', 'log2']  # Number of features to consider for best split    
}
# Best Hyperparameters

# Initialize Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# Perform Grid Search with 5-fold cross-validation
grid_search = GridSearchCV(rf_model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train_rf, y_train_res_encoded)

# Best hyperparameter values
best_params_rf = grid_search.best_params_
print("Best Hyperparameters:", best_params_rf)
# Out:
# Best Hyperparameters: {'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 50}

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_best_model = RandomForestClassifier(**best_params_rf, random_state=42)
rf_best_model.fit(X_train_rf, y_train_res_encoded)
# Out:
# RandomForestClassifier(max_depth=8, max_features='log2', min_samples_leaf=10,
#                        min_samples_split=10, n_estimators=50, random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
# Generate predictions on training data
y_train_pred_rf_best = rf_best_model.predict(X_train_rf)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
accuracy_rf_best = accuracy_score(y_train_res_encoded, y_train_pred_rf_best)
print(f"Optimized Random Forest Model Accuracy: {accuracy_rf_best:.2f}")
# Out:
# Optimized Random Forest Model Accuracy: 0.90

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
# Create the confusion matrix
# Generate confusion matrix
conf_matrix_rf_best = confusion_matrix(y_train_res_encoded, y_train_pred_rf_best)
print("Confusion Matrix:\n", conf_matrix_rf_best)
# Out:
# Confusion Matrix:
#  [[401  65]
#  [ 25 441]]

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN_rf_best, FP_rf_best, FN_rf_best, TP_rf_best = conf_matrix_rf_best.ravel()

print(f"True Positives: {TP_rf_best}, True Negatives: {TN_rf_best}, False Positives: {FP_rf_best}, False Negatives: {FN_rf_best}")
# Out:
# True Positives: 441, True Negatives: 401, False Positives: 65, False Negatives: 25

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_rf_best = TP_rf_best / (TP_rf_best + FN_rf_best) if (TP_rf_best + FN_rf_best) > 0 else 0

# Calculate the specificity
specificity_rf_best = TN_rf_best / (TN_rf_best + FP_rf_best) if (TN_rf_best + FP_rf_best) > 0 else 0

# Calculate Precision
precision_rf_best = precision_score(y_train_res_encoded, y_train_pred_rf_best)

# Calculate Recall
recall_rf_best = recall_score(y_train_res_encoded, y_train_pred_rf_best)

# Calculate F1-Score
f1_score_rf_best = 2 * (precision_rf_best * recall_rf_best) / (precision_rf_best + recall_rf_best) if (precision_rf_best + recall_rf_best) > 0 else 0

print(f"Sensitivity: {sensitivity_rf_best:.2f}")
print(f"Specificity: {specificity_rf_best:.2f}")
print(f"Precision: {precision_rf_best:.2f}")
print(f"Recall: {recall_rf_best:.2f}")
print(f"F1 Score: {f1_score_rf_best:.2f}")
# Out:
# Sensitivity: 0.95
# Specificity: 0.86
# Precision: 0.87
# Recall: 0.95
# F1 Score: 0.91

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
import statsmodels.api as sm
# Select the relevant features for validation data
#X_test_final = X_test_scaled[selected_features]
# Add constant to X_validation
X_test_final = sm.add_constant(X_test_final)

# Verify data shape
print("Validation Data Shape:", X_test_final.shape)
# Out:
# Validation Data Shape: (273, 25)

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
print("Training features:", X_train_final.columns.tolist())
print("Validation features:", X_test_final.columns.tolist())
# Out:
# Training features: ['const', 'insured_occupation_exec-managerial', 'insured_hobbies_board-games', 'insured_hobbies_camping', 'insured_hobbies_chess', 'insured_hobbies_cross-fit', 'insured_hobbies_dancing', 'insured_hobbies_exercise', 'insured_hobbies_golf', 'insured_hobbies_sleeping', 'insured_hobbies_video-games', 'insured_hobbies_yachting', 'collision_type_Rear Collision', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage', 'incident_state_WV', 'auto_model_Camry', 'auto_model_Civic', 'auto_model_Grand Cherokee', 'auto_model_Legacy', 'auto_model_Neon', 'auto_model_Other', 'auto_model_Wrangler', 'auto_model_X6']
# Validation features: ['const', 'insured_occupation_exec-managerial', 'insured_hobbies_board-games', 'insured_hobbies_camping', 'insured_hobbies_chess', 'insured_hobbies_cross-fit', 'insured_hobbies_dancing', 'insured_hobbies_exercise', 'insured_hobbies_golf', 'insured_hobbies_sleeping', 'insured_hobbies_video-games', 'insured_hobbies_yachting', 'collision_type_Rear Collision', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage', 'incident_state_WV', 'auto_model_Camry', 'auto_model_Civic', 'auto_model_Grand Cherokee', 'auto_model_Legacy', 'auto_model_Neon', 'auto_model_Other', 'auto_model_Wrangler', 'auto_model_X6']

# %%
y_test_pred_prob = log_model_fit.predict(X_test_final)

# Reshape probabilities into an array
y_test_pred_prob = y_test_pred_prob.values.reshape(-1, 1)

print("Predicted probabilities:\n", y_test_pred_prob[:10])
# Out:
# Predicted probabilities:
#  [[0.06127777]
#  [0.9063285 ]
#  [0.69773229]
#  [0.85685633]
#  [0.92277492]
#  [0.92277492]
#  [0.13992004]
#  [0.02870419]
#  [0.85046627]
#  [0.01258796]]

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
val_results_df = pd.DataFrame({
    "Actual_Fraud": y_test_encoded,
    "Predicted_Probability": y_test_pred_prob.flatten()
})

print(val_results_df.head())
# Out:
#    Actual_Fraud  Predicted_Probability
# 0             0               0.061278
# 1             0               0.906329
# 2             1               0.697732
# 3             0               0.856856
# 4             0               0.922775

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
val_results_df['Final_Predicted_Fraud'] = (val_results_df['Predicted_Probability'] >= optimal_cutoff).astype(int)

print(val_results_df.head())
# Out:
#    Actual_Fraud  Predicted_Probability  Final_Predicted_Fraud
# 0             0               0.061278                      0
# 1             0               0.906329                      1
# 2             1               0.697732                      1
# 3             0               0.856856                      1
# 4             0               0.922775                      1

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
from sklearn.metrics import accuracy_score
# Check the accuracy
accuracy_val = accuracy_score(y_test_encoded, val_results_df["Final_Predicted_Fraud"])
print(f"Model Accuracy on Validation Data: {accuracy_val:.2f}")
# Out:
# Model Accuracy on Validation Data: 0.81

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_val = confusion_matrix(y_test_encoded, val_results_df["Final_Predicted_Fraud"])

print("Confusion Matrix:\n", conf_matrix_val)
# Out:
# Confusion Matrix:
#  [[160  41]
#  [ 10  62]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
# Extract values from confusion matrix
TN_val, FP_val, FN_val, TP_val = conf_matrix_val.ravel()

print(f"True Positives: {TP_val}, True Negatives: {TN_val}, False Positives: {FP_val}, False Negatives: {FN_val}")
# Out:
# True Positives: 62, True Negatives: 160, False Positives: 41, False Negatives: 10

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_val = TP_val / (TP_val + FN_val) if (TP_val + FN_val) > 0 else 0

# Calculate the specificity
specificity_val = TN_val / (TN_val + FP_val) if (TN_val + FP_val) > 0 else 0

# Calculate Precision
precision_val = precision_score(y_test_encoded, val_results_df["Final_Predicted_Fraud"])

# Calculate Recall
recall_val = recall_score(y_test_encoded, val_results_df["Final_Predicted_Fraud"])

# Calculate F1 Score
f1_score_val = 2 * (precision_val * recall_val) / (precision_val + recall_val) if (precision_val + recall_val) > 0 else 0

print(f"Sensitivity: {sensitivity_val:.2f}")
print(f"Specificity: {specificity_val:.2f}")
print(f"Precision: {precision_val:.2f}")
print(f"Recall: {recall_val:.2f}")
print(f"F1 Score: {f1_score_val:.2f}")
# Out:
# Sensitivity: 0.86
# Specificity: 0.80
# Precision: 0.60
# Recall: 0.86
# F1 Score: 0.71

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
X_test_rf_final = X_test_scaled[selected_features_rf]

# Make predictions on validation data using the optimized Random Forest model
y_test_pred_rf = rf_best_model.predict(X_test_rf_final)

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
accuracy_rf_val = accuracy_score(y_test_encoded, y_test_pred_rf)
print(f"Random Forest Model Accuracy on Validation Data: {accuracy_rf_val:.2f}")
# Out:
# Random Forest Model Accuracy on Validation Data: 0.79

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_rf_val = confusion_matrix(y_test_encoded, y_test_pred_rf)

print("Confusion Matrix:\n", conf_matrix_rf_val)
# Out:
# Confusion Matrix:
#  [[162  39]
#  [ 18  54]]

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
# Extract confusion matrix values
TN_rf_val, FP_rf_val, FN_rf_val, TP_rf_val = conf_matrix_rf_val.ravel()

print(f"True Positives: {TP_rf_val}")
print(f"True Negatives: {TN_rf_val}")
print(f"False Positives: {FP_rf_val}")
print(f"False Negatives: {FN_rf_val}")
# Out:
# True Positives: 54
# True Negatives: 162
# False Positives: 39
# False Negatives: 18

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity_rf_val = TP_rf_val / (TP_rf_val + FN_rf_val) if (TP_rf_val + FN_rf_val) > 0 else 0

# Calculate Specificity
specificity_rf_val = TN_rf_val / (TN_rf_val + FP_rf_val) if (TN_rf_val + FP_rf_val) > 0 else 0

# Calculate Precision
precision_rf_val = precision_score(y_test, y_test_pred_rf)

# Calculate Recall
recall_rf_val = recall_score(y_test, y_test_pred_rf)

# Calculate F1-score
f1_score_rf_val = 2 * (precision_rf_val * recall_rf_val) / (precision_rf_val + recall_rf_val) if (precision_rf_val + recall_rf_val) > 0 else 0

print(f"Sensitivity: {sensitivity_rf_val:.2f}")
print(f"Specificity: {specificity_rf_val:.2f}")
print(f"Precision: {precision_rf_val:.2f}")
print(f"Recall: {recall_rf_val:.2f}")
print(f"F1 Score: {f1_score_rf_val:.2f}")
# Out:
# Sensitivity: 0.75
# Specificity: 0.81
# Precision: 0.58
# Recall: 0.75
# F1 Score: 0.65

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.

# %%
# Create summary DataFrame
model_comparison = pd.DataFrame({
    "Metric": ["Accuracy", "Sensitivity (Recall)", "Specificity", "Precision", "F1 Score"],
    "Logistic Regression": [accuracy_val, sensitivity_val, specificity_val, precision_val, f1_score_val],
    "Random Forest": [accuracy_rf_val, sensitivity_rf_val, specificity_rf_val, precision_rf_val, f1_score_rf_val]
})

print(model_comparison)
# Out:
#                  Metric  Logistic Regression  Random Forest
# 0              Accuracy             0.813187       0.791209
# 1  Sensitivity (Recall)             0.861111       0.750000
# 2           Specificity             0.796020       0.805970
# 3             Precision             0.601942       0.580645
# 4              F1 Score             0.708571       0.654545

# %%
# Plot performance comparison
plt.figure(figsize=(10, 6))
metrics = model_comparison["Metric"]
log_reg_values = model_comparison["Logistic Regression"]
rf_values = model_comparison["Random Forest"]

plt.plot(metrics, log_reg_values, marker='o', label="Logistic Regression", color="blue")
plt.plot(metrics, rf_values, marker='s', label="Random Forest", color="green")

plt.xlabel("Evaluation Metric")
plt.ylabel("Score")
plt.title("Performance Comparison: Logistic Regression vs Random Forest")
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import numpy as np

# Define confusion matrices
conf_matrix_lr = np.array([[106, 95], [35, 37]])
conf_matrix_rf = np.array([[157, 44], [51, 21]])

# Plot Logistic Regression Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix_lr, annot=True, fmt='d', cmap="Blues", xticklabels=["Predicted Legitimate", "Predicted Fraud"], 
            yticklabels=["Actual Legitimate", "Actual Fraud"])
plt.title("Logistic Regression Confusion Matrix")
plt.show()

# Plot Random Forest Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix_rf, annot=True, fmt='d', cmap="Greens", xticklabels=["Predicted Legitimate", "Predicted Fraud"], 
            yticklabels=["Actual Legitimate", "Actual Fraud"])
plt.title("Random Forest Confusion Matrix")
plt.show()
